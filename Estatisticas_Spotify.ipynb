# %% [markdown]
# # Importando pacotes

# %%
# analíse explorátoria e limpeza de dados
import pandas as pd 

# plotagem de gráficos
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregando os dados

# %%
df = pd.read_csv(r"C:\Users\renil\Desktop\Projetos\Spotify_2024_Global_Streaming_Data.csv")

# %% [markdown]
# # Vizualizando as 10 primeiras linhas

# %%
df.head(10)
# Out:
#           Country         Artist                                Album  \
# 0         Germany   Taylor Swift              1989 (Taylor's Version)
# 1          Brazil     The Weeknd                          After Hours
# 2   United States    Post Malone                               Austin
# 3           Italy     Ed Sheeran                    Autumn Variations
# 4           Italy     Ed Sheeran                    Autumn Variations
# 5          Sweden  Billie Eilish                    Happier Than Ever
# 6          France      Bad Bunny  Nadie Sabe Lo Que Va a Pasar Mañana
# 7          France       Doja Cat                              Scarlet
# 8          Sweden      Bad Bunny  Nadie Sabe Lo Que Va a Pasar Mañana
# 9  United Kingdom  Ariana Grande                     Eternal Sunshine
#
#        Genre  Release Year  Monthly Listeners (Millions)  \
# 0      K-pop          2019                         23.10
# 1        R&B          2022                         60.60
# 2  Reggaeton          2023                         42.84
# 3      K-pop          2018                         73.24
# 4        R&B          2023                          7.89
# 5      Indie          2019                         37.65
# 6       Rock          2021                         27.72
# 7        Pop          2020                         40.72
# 8      K-pop          2019                         25.42
# 9       Rock          2018                         75.82
#
#    Total Streams (Millions)  Total Hours Streamed (Millions)  \
# 0                   3695.53                         14240.35
# 1                   2828.16                         11120.44
# 2                   1425.46                          4177.49
# 3                   2704.33                         12024.08
# 4                   3323.25                         13446.32
# 5                   1087.06                          3298.09
# 6                   4630.69                         17950.05
# 7                    377.63                          1633.73
# 8                   2828.77                          8558.40
# 9                   4312.46                         12099.39
#
#    Avg Stream Duration (Min) Platform Type  Streams Last 30 Days (Millions)  \
# 0                       4.28          Free                           118.51
# 1                       3.90       Premium                            44.87
# 2                       4.03          Free                            19.46
# 3                       3.26       Premium                           166.05
# 4                       4.47          Free                           173.43
# 5                       4.37          Free                           122.22
# 6                       2.94       Premium                           168.73
# 7                       3.63       Premium                            43.31
# 8                       3.67       Premium                            73.04
# 9                       2.82       Premium                           119.69
#
#    Skip Rate (%)
# 0           2.24
# 1          23.98
# 2           4.77
# 3          25.12
# 4          15.82
# 5           7.67
# 6          31.26
# 7          20.47
# 8          39.90
# 9          16.01

# %% [markdown]
# # Procurando por dados duplicados e faltantes

# %%
df.duplicated().value_counts()
# Out:
# False    500
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                            0
# Artist                             0
# Album                              0
# Genre                              0
# Release Year                       0
# Monthly Listeners (Millions)       0
# Total Streams (Millions)           0
# Total Hours Streamed (Millions)    0
# Avg Stream Duration (Min)          0
# Platform Type                      0
# Streams Last 30 Days (Millions)    0
# Skip Rate (%)                      0
# dtype: int64

# %% [markdown]
# como podemos observar, o dataset não apresenta dados faltantes para atrapalhar as análises, então vamos a esta etapa

# %% [markdown]
# # Análise exploratória

# %% [markdown]
# ## Estilo mais ouvido por país

# %%
genero_por_pais = pd.crosstab(df['Country'] , df['Genre'])

styled_table = genero_por_pais.style.background_gradient(cmap= 'coolwarm')
display(styled_table)
# Out:
# <style type="text/css">
# #T_da03a_row0_col0, #T_da03a_row1_col3, #T_da03a_row3_col3, #T_da03a_row4_col0, #T_da03a_row6_col0, #T_da03a_row7_col0, #T_da03a_row7_col5, #T_da03a_row8_col5, #T_da03a_row9_col5, #T_da03a_row10_col0, #T_da03a_row13_col3, #T_da03a_row13_col5, #T_da03a_row14_col5, #T_da03a_row16_col0, #T_da03a_row18_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_da03a_row0_col1, #T_da03a_row0_col8, #T_da03a_row1_col4, #T_da03a_row1_col8, #T_da03a_row2_col1, #T_da03a_row2_col8, #T_da03a_row5_col4, #T_da03a_row6_col2, #T_da03a_row7_col2, #T_da03a_row9_col4, #T_da03a_row10_col8, #T_da03a_row11_col1, #T_da03a_row11_col8, #T_da03a_row13_col4, #T_da03a_row15_col2, #T_da03a_row15_col4, #T_da03a_row16_col9, #T_da03a_row18_col1, #T_da03a_row19_col1, #T_da03a_row19_col2, #T_da03a_row19_col4, #T_da03a_row19_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_da03a_row0_col2, #T_da03a_row0_col4, #T_da03a_row2_col9, #T_da03a_row5_col8, #T_da03a_row5_col9, #T_da03a_row6_col4, #T_da03a_row6_col8, #T_da03a_row6_col9, #T_da03a_row7_col9, #T_da03a_row8_col4, #T_da03a_row8_col8, #T_da03a_row9_col1, #T_da03a_row9_col8, #T_da03a_row9_col9, #T_da03a_row12_col2, #T_da03a_row12_col4, #T_da03a_row12_col8, #T_da03a_row13_col1, #T_da03a_row14_col1, #T_da03a_row14_col2, #T_da03a_row16_col4, #T_da03a_row17_col2, #T_da03a_row18_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_da03a_row0_col3, #T_da03a_row6_col3, #T_da03a_row9_col3, #T_da03a_row11_col5, #T_da03a_row12_col5, #T_da03a_row15_col5, #T_da03a_row18_col3, #T_da03a_row19_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_da03a_row0_col5, #T_da03a_row2_col6, #T_da03a_row8_col1, #T_da03a_row8_col7, #T_da03a_row9_col2, #T_da03a_row10_col9, #T_da03a_row12_col7, #T_da03a_row13_col8, #T_da03a_row15_col0, #T_da03a_row15_col7, #T_da03a_row16_col1, #T_da03a_row16_col3, #T_da03a_row17_col4, #T_da03a_row17_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_da03a_row0_col6 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_da03a_row0_col7, #T_da03a_row3_col7, #T_da03a_row4_col7, #T_da03a_row9_col7, #T_da03a_row10_col7, #T_da03a_row16_col7, #T_da03a_row18_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_da03a_row0_col9, #T_da03a_row1_col1, #T_da03a_row2_col4, #T_da03a_row3_col1, #T_da03a_row3_col9, #T_da03a_row4_col1, #T_da03a_row4_col4, #T_da03a_row4_col9, #T_da03a_row5_col1, #T_da03a_row5_col2, #T_da03a_row6_col1, #T_da03a_row7_col4, #T_da03a_row8_col9, #T_da03a_row11_col2, #T_da03a_row11_col4, #T_da03a_row11_col9, #T_da03a_row13_col2, #T_da03a_row14_col8, #T_da03a_row15_col1, #T_da03a_row16_col2, #T_da03a_row18_col9, #T_da03a_row19_col9 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_da03a_row1_col0, #T_da03a_row1_col2, #T_da03a_row1_col7, #T_da03a_row1_col9, #T_da03a_row3_col4, #T_da03a_row3_col8, #T_da03a_row4_col8, #T_da03a_row5_col0, #T_da03a_row7_col8, #T_da03a_row9_col6, #T_da03a_row10_col2, #T_da03a_row15_col8, #T_da03a_row16_col8, #T_da03a_row17_col1, #T_da03a_row17_col3, #T_da03a_row17_col5, #T_da03a_row17_col8, #T_da03a_row18_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_da03a_row1_col5, #T_da03a_row2_col5, #T_da03a_row3_col5, #T_da03a_row4_col3, #T_da03a_row4_col5, #T_da03a_row5_col3, #T_da03a_row5_col5, #T_da03a_row6_col5, #T_da03a_row8_col3, #T_da03a_row10_col3, #T_da03a_row10_col5, #T_da03a_row11_col0, #T_da03a_row12_col3, #T_da03a_row14_col3, #T_da03a_row15_col3, #T_da03a_row18_col0, #T_da03a_row19_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_da03a_row1_col6, #T_da03a_row4_col6, #T_da03a_row5_col6, #T_da03a_row7_col6, #T_da03a_row10_col6, #T_da03a_row13_col6, #T_da03a_row15_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_da03a_row2_col0, #T_da03a_row2_col3, #T_da03a_row7_col3, #T_da03a_row11_col3, #T_da03a_row16_col5, #T_da03a_row17_col0, #T_da03a_row19_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_da03a_row2_col2, #T_da03a_row3_col2, #T_da03a_row4_col2, #T_da03a_row7_col1, #T_da03a_row8_col2, #T_da03a_row10_col1, #T_da03a_row10_col4, #T_da03a_row12_col1, #T_da03a_row12_col9, #T_da03a_row13_col9, #T_da03a_row14_col4, #T_da03a_row14_col9, #T_da03a_row15_col9, #T_da03a_row18_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_da03a_row2_col7, #T_da03a_row6_col6, #T_da03a_row6_col7, #T_da03a_row8_col6, #T_da03a_row11_col7, #T_da03a_row12_col6, #T_da03a_row14_col7, #T_da03a_row16_col6, #T_da03a_row19_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_da03a_row3_col0, #T_da03a_row12_col0, #T_da03a_row13_col0, #T_da03a_row14_col0 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_da03a_row3_col6, #T_da03a_row11_col6, #T_da03a_row14_col6, #T_da03a_row17_col6, #T_da03a_row19_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_da03a_row5_col7, #T_da03a_row7_col7, #T_da03a_row13_col7, #T_da03a_row17_col7 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_da03a_row8_col0, #T_da03a_row9_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_da03a_row18_col6 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# </style>
# <table id="T_da03a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Genre</th>
#       <th id="T_da03a_level0_col0" class="col_heading level0 col0" >Classical</th>
#       <th id="T_da03a_level0_col1" class="col_heading level0 col1" >EDM</th>
#       <th id="T_da03a_level0_col2" class="col_heading level0 col2" >Hip Hop</th>
#       <th id="T_da03a_level0_col3" class="col_heading level0 col3" >Indie</th>
#       <th id="T_da03a_level0_col4" class="col_heading level0 col4" >Jazz</th>
#       <th id="T_da03a_level0_col5" class="col_heading level0 col5" >K-pop</th>
#       <th id="T_da03a_level0_col6" class="col_heading level0 col6" >Pop</th>
#       <th id="T_da03a_level0_col7" class="col_heading level0 col7" >R&B</th>
#       <th id="T_da03a_level0_col8" class="col_heading level0 col8" >Reggaeton</th>
#       <th id="T_da03a_level0_col9" class="col_heading level0 col9" >Rock</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da03a_level0_row0" class="row_heading level0 row0" >Argentina</th>
#       <td id="T_da03a_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_da03a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_da03a_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_da03a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_da03a_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_da03a_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_da03a_row0_col6" class="data row0 col6" >5</td>
#       <td id="T_da03a_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_da03a_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_da03a_row0_col9" class="data row0 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_da03a_level0_row1" class="row_heading level0 row1" >Australia</th>
#       <td id="T_da03a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_da03a_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_da03a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_da03a_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_da03a_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_da03a_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_da03a_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_da03a_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_da03a_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_da03a_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da03a_le

# %% [markdown]
# ## Artistas mais ouvidos

# %%
artista_mais_ouvidos = df.groupby('Artist')['Monthly Listeners (Millions)'].sum()

fig, ax = plt.subplots(figsize= (10, 6))
ax.bar(artista_mais_ouvidos.index, artista_mais_ouvidos.values)

ax.set_xlabel('Artistas' , fontsize= 12)
ax.set_ylabel('Ouvintes mensais (milhões)' , fontsize= 12)
ax.set_title('Artistas mais ouvidos', fontsize= 12)
plt.xticks(rotation= 45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Artistas mais ouvidos por país

# %%
artista_por_pais = pd.crosstab(df['Artist'] , df['Country'])

styled_table = artista_por_pais.style.background_gradient(cmap='coolwarm')
display(styled_table)
# Out:
# <style type="text/css">
# #T_d9af2_row0_col0, #T_d9af2_row5_col3, #T_d9af2_row7_col0, #T_d9af2_row9_col3, #T_d9af2_row10_col3, #T_d9af2_row12_col13, #T_d9af2_row13_col13 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_d9af2_row0_col1, #T_d9af2_row0_col5, #T_d9af2_row0_col9, #T_d9af2_row0_col14, #T_d9af2_row1_col1, #T_d9af2_row1_col3, #T_d9af2_row1_col7, #T_d9af2_row2_col0, #T_d9af2_row2_col3, #T_d9af2_row2_col8, #T_d9af2_row2_col10, #T_d9af2_row2_col12, #T_d9af2_row3_col2, #T_d9af2_row3_col6, #T_d9af2_row4_col1, #T_d9af2_row4_col2, #T_d9af2_row4_col5, #T_d9af2_row4_col6, #T_d9af2_row5_col2, #T_d9af2_row5_col6, #T_d9af2_row5_col8, #T_d9af2_row5_col10, #T_d9af2_row5_col11, #T_d9af2_row5_col13, #T_d9af2_row5_col18, #T_d9af2_row6_col1, #T_d9af2_row6_col2, #T_d9af2_row6_col9, #T_d9af2_row6_col15, #T_d9af2_row7_col5, #T_d9af2_row7_col8, #T_d9af2_row7_col9, #T_d9af2_row7_col10, #T_d9af2_row7_col11, #T_d9af2_row8_col0, #T_d9af2_row8_col3, #T_d9af2_row8_col16, #T_d9af2_row8_col18, #T_d9af2_row9_col2, #T_d9af2_row9_col7, #T_d9af2_row9_col8, #T_d9af2_row9_col13, #T_d9af2_row10_col2, #T_d9af2_row10_col5, #T_d9af2_row10_col10, #T_d9af2_row10_col14, #T_d9af2_row10_col17, #T_d9af2_row11_col2, #T_d9af2_row11_col11, #T_d9af2_row11_col17, #T_d9af2_row12_
{
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d9af2_row1_col6, #T_d9af2_row1_col14, #T_d9af2_row2_col14, #T_d9af2_row5_col14 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_d9af2_row3_col14, #T_d9af2_row4_col14, #T_d9af2_row7_col6, #T_d9af2_row8_col6, #T_d9af2_row9_col14, #T_d9af2_row11_col14, #T_d9af2_row12_col6, #T_d9af2_row12_col14, #T_d9af2_row14_col14 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d9af2_row4_col13, #T_d9af2_row6_col3, #T_d9af2_row11_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d9af2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th id="T_d9af2_level0_col0" class="col_heading level0 col0" >Argentina</th>
#       <th id="T_d9af2_level0_col1" class="col_heading level0 col1" >Australia</th>
#       <th id="T_d9af2_level0_col2" class="col_heading level0 col2" >Brazil</th>
#       <th id="T_d9af2_level0_col3" class="col_heading level0 col3" >Canada</th>
#       <th id="T_d9af2_level0_col4" class="col_heading level0 col4" >France</th>
#       <th id="T_d9af2_level0_col5" class="col_heading level0 col5" >Germany</th>
#       <th id="T_d9af2_level0_col6" class="col_heading level0 col6" >India</th>
#       <th id="T_d9af2_level0_col7" class="col_heading level0 col7" >Indonesia</th>
#       <th id="T_d9af2_level0_col8" class="col_heading level0 col8" >Italy</th>
#       <th id="T_d9af2_level0_col9" class="col_heading level0 col9" >Japan</th>
#       <th id="T_d9af2_level0_col10" class="col_heading level0 col10" >

# %% [markdown]
# ## Álbum mais ouvido

# %%
albuns_mais_ouvidos = df.groupby('Album')['Total Streams (Millions)'].sum()

albuns_mais_ouvidos = albuns_mais_ouvidos.sort_values(ascending= False)

fig, ax = plt.subplots(figsize= (10, 6))
ax.bar(albuns_mais_ouvidos.index, albuns_mais_ouvidos.values, color='purple')

ax.set_xlabel('Álbum', fontsize= 12)
ax.set_ylabel('Total de streams (milhões)' , fontsize= 12)
ax.set_title('Álbuns mais ouvidos', fontsize= 16)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Álbuns que foram mais pulados

# %%
albuns_mais_pulados = df.sort_values(by= 'Skip Rate (%)', ascending=False)


fig, ax = plt.subplots(figsize= (10, 6))
ax.bar(albuns_mais_pulados['Album'], albuns_mais_pulados['Skip Rate (%)'], color='red')


ax.set_xlabel('Álbum', fontsize= 12)
ax.set_ylabel('Taxa de rejeição (%)', fontsize= 12)
ax.set_title('Álbuns Mais Pulados', fontsize= 16)
plt.xticks(rotation=45, ha='right')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Agora, vamos fazer algumas analises em relação a assinatura Premium

# %% [markdown]
# ## Quais álbuns mais ouvidos por usuários gratuitos

# %%
usuarios_gratuitos = df[df["Platform Type"] == "Free"]

albuns_gratis = usuarios_gratuitos.groupby("Album")["Total Hours Streamed (Millions)"].sum().sort_values(ascending= False)

plt.figure(figsize= (8, 5))
albuns_gratis.plot(kind="barh", color="skyblue")
plt.title("Albuns mais ouvidos por usuários grátis", fontsize= 14)
plt.xlabel("Ouvintes (milhões)", fontsize= 12)
plt.ylabel("Quantidade de Usuários grátis", fontsize= 12)
plt.xticks(rotation= 30, ha= 'right', fontsize=10 )
plt.grid(axis='y', linestyle='--', alpha= 0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Álbuns mais ouvidos por premiums

# %%
usuarios_premium = df[df["Platform Type"] == "Premium"]

albuns_premium = usuarios_premium.groupby('Album')["Total Hours Streamed (Millions)"].sum().sort_values(ascending=False)

plt.figure(figsize=( 8, 5))
albuns_premium.plot(kind="barh", color="skyblue")
plt.title("Álbuns mais ouvidos por usuários premium", fontsize= 14)
plt.xlabel("Ouvintes (milhões)", fontsize= 12)
plt.ylabel("Quantidade de Usuários Premium", fontsize= 12)
plt.xticks(rotation= 30, ha= 'right', fontsize=10 )
plt.grid(axis='y', linestyle='--', alpha= 0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## País com mais contas premium

# %%
usuarios_premium = df[df["Platform Type"] == "Premium"]
contas_premium = usuarios_premium["Country"].value_counts()

plt.figure(figsize= (10, 6))
contas_premium.plot(kind="bar", color= "skyblue", edgecolor= "black")

plt.title("Usuários Premium por País", fontsize=16)
plt.xlabel("País", fontsize=12)
plt.ylabel("Quantidade de Usuários Premium", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## País com mais usuários gratuitos

# %%
usuarios_gratuitos = df[df["Platform Type"] == "Free"]
contas_gratuitas = usuarios_gratuitos["Country"].value_counts()

plt.figure(figsize= (10, 6))
contas_gratuitas.plot(kind = "barh", color = "lightcoral", edgecolor= "black")

plt.title("Usuários Gratuitos por País", fontsize= 16)
plt.xlabel("Quantidade de Usuários Gratuitos (milhões)", fontsize= 12)
plt.ylabel("País", fontsize= 12)
plt.xticks(rotation=45, ha= 'right')
plt.grid(axis= 'y', linestyle= '--', alpha= 0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusão
# ## A partir da exploração destes dados, chegamos a algumas conclusões e podemos observar alguns pontos:

# %% [markdown]
# ### Tendências regionais como por exemplo a forte influência de Kpop e Pop na Argetina e no Brasil e a forte forte influência do Hip hop no Japão.
# ### Artistas mais ouvidos, sendo os 3 mais ouvidos: Arianna Grande, BTS e Blackpink.
# ### Quais artistas são mais populares em cada país contido no conjunto de dados.
# ### Álbuns mais ouvidos, sendo os 3 mais ouvidos: Proof do BTS, Future Nostalgia da Dua Lipa e nadie sabe lo que va a pasar mañana do Bad Bunny.
# ### Quais são os albuns mais pulados sendo os 3 mais pulados: Eternal Sunshine da Ariana Grande, em segundo Nadie sabe lo que va a pasar mañana e Scarlet da Doja Cat.
# ### Os países com mais usuários gratuitos, sendo os 3 primeiros: Coreia do Sul, Russia e Suéçia.
# ### Os países com mais usuários premium, snedo eles: Itália, México e Brasil
# ### Os álbuns mais ouvidos por usuários gratuitos, sendo os 3 primeiros: Nadie sabe lo que va a pasar mañana, Guts da Olivia Rodrigo e Autumn Variations do Ed Sheeran
# ### E também os mais ouvidos pelos premiums, sendo os 3 primeiros Nadie sabe lo que va a pasar mañana, Guts e Autumn Variations.
